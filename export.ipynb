# %%
# %run model.ipynb

# %%
model = MaskRCNN_MobileNetV3_FPN()

input = t.rand(1, 3, 1920, 1080)

t.onnx.export(
    model,
    input,
    "maskrcnn_mobilenetv3_fpn_float.onnx",
    verbose=False,
    input_names=['input'],
    output_names=['boxes', 'labels', 'scores', 'masks'],
)
# Out:
# /home/jack/.local/share/virtualenvs/datadev-5ox7fytP/lib/python3.10/site-packages/torchvision/ops/boxes.py:157: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   boxes_x = torch.min(boxes_x, torch.tensor(width, dtype=boxes.dtype, device=boxes.device))
# /home/jack/.local/share/virtualenvs/datadev-5ox7fytP/lib/python3.10/site-packages/torchvision/ops/boxes.py:159: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   boxes_y = torch.min(boxes_y, torch.tensor(height, dtype=boxes.dtype, device=boxes.device))
# ...

# %%
import onnxruntime as ort
import numpy as np
import onnx

ort_session = ort.InferenceSession("maskrcnn_mobilenetv3_fpn_float.onnx")

output = ort_session.run(None, {"input": input.numpy()})

output
# Out:
# 2024-09-17 11:34:01.105255751 [W:onnxruntime:, graph.cc:3593 CleanUnusedInitializersAndNodeArgs] Removing initializer '1744'. It is not used by any node and should be removed from the model.
# 2024-09-17 11:34:01.105276232 [W:onnxruntime:, graph.cc:3593 CleanUnusedInitializersAndNodeArgs] Removing initializer '1748'. It is not used by any node and should be removed from the model.
# 2024-09-17 11:34:01.105290052 [W:onnxruntime:, graph.cc:3593 CleanUnusedInitializersAndNodeArgs] Removing initializer '2310'. It is not used by any node and should be removed from the model.
# 2024-09-17 11:34:01.105294192 [W:onnxruntime:, graph.cc:3593 CleanUnusedInitializersAndNodeArgs] Removing initializer '2314'. It is not used by any node and should be removed from the model.
# 2024-09-17 11:34:01.105447493 [W:onnxruntime:, graph.cc:3593 CleanUnusedInitializersAndNodeArgs] Removing initializer '2801'. It is not used by any node and should be removed from the model.
# ...
